# %% [markdown]
# <a href="https://colab.research.google.com/github/KiranSinha872/data_science_june/blob/main/python01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello")
a=2
print(a*a)
name="kiran"
print(name)



#input
k=int(input())
print(k)
print(type(k))

surname=input()
print(surname)
print(type(surname))



p=int(input())
q=int(input())
r=int(input())
print(p+q+r)

# %%
#even or odd

x=int(input())

if(x%2==0):
  print("even")
else:
  print("odd")


  #if elif else



#for loop
# for(int i=0,i<n;i++)


# (start,stop,steps)
for i in range(1, 11, 2):
  print(i)

# %%
# palindrome



s=input()
n=len(s)
i=0
j=n-1
while(i<j):
  if(s[i]==s[j]):
    i=i+1
    j=j-1
  else:
    print("not palindrome")
    break

print("palindrome")
